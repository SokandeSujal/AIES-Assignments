# %% [markdown]
# # Assignment 2: Hill Climbing for TSP
# Using 2-opt swaps to improve a tour of cities.

# %%
import math
import random

def distance(c1, c2):
    return math.sqrt((c1[0]-c2[0])**2 + (c1[1]-c2[1])**2)

def total_distance(cities, tour):
    n = len(tour)
    return sum(distance(cities[tour[i]], cities[tour[(i+1)%n]]) for i in range(n))

def two_opt_swap(tour, i, j):
    return tour[:i] + tour[i:j+1][::-1] + tour[j+1:]

def hill_climbing(cities):
    tour = list(range(len(cities)))
    random.shuffle(tour)
    current_dist = total_distance(cities, tour)

    improved = True
    while improved:
        improved = False
        for i in range(1, len(tour)-1):
            for j in range(i+1, len(tour)):
                new_tour = two_opt_swap(tour, i, j)
                new_dist = total_distance(cities, new_tour)
                if new_dist < current_dist:
                    tour = new_tour
                    current_dist = new_dist
                    improved = True
                    break
            if improved:
                break

    return tour, current_dist

# %% [markdown]
# ## Basic run

# %%
cities = [(0,0), (1,5), (4,1), (4,4), (2,2)]

tour, dist = hill_climbing(cities)
print("Tour:", tour)
print("Distance:", round(dist, 2))
# Out:
# Tour: [1, 3, 2, 0, 4]
# Distance: 16.28

# %% [markdown]
# ## Running multiple times to see different results
# Hill climbing can give different results each run because of the random start.

# %%
results = []
for i in range(5):
    tour, dist = hill_climbing(cities)
    results.append((round(dist, 2), tour))
    print(f"Run {i+1}: distance = {round(dist,2)}, tour = {tour}")

best = min(results)
print("\nBest distance:", best[0])
print("Best tour:", best[1])
# Out:
# Run 1: distance = 16.28, tour = [0, 2, 3, 1, 4]
# Run 2: distance = 16.28, tour = [4, 1, 3, 2, 0]
# Run 3: distance = 16.28, tour = [2, 0, 4, 1, 3]
# Run 4: distance = 16.28, tour = [0, 2, 3, 1, 4]
# Run 5: distance = 16.28, tour = [4, 1, 3, 2, 0]
#
# Best distance: 16.28
# Best tour: [0, 2, 3, 1, 4]

# %% [markdown]
# ## Testing with more cities

# %%
more_cities = [(0,0),(1,5),(4,1),(4,4),(2,2),(3,6),(6,3),(5,0)]

best_dist = float('inf')
best_tour = None

for _ in range(10):
    tour, dist = hill_climbing(more_cities)
    if dist < best_dist:
        best_dist = dist
        best_tour = tour

print("Best tour found:", best_tour)
print("Best distance:", round(best_dist, 2))
# Out:
# Best tour found: [3, 6, 7, 2, 0, 4, 1, 5]
# Best distance: 21.4
